# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from scipy import io
import os
import glob

# %%
from IPython.display import HTML

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
sns.set_style('white')
sns.set_style('ticks')
sns.set_palette('muted')
sns.set_color_codes('muted')

# %%
## Desktop
filepath = '/Users/frankanayet/Google Drive/NLineData/Beh_Data'
os.chdir(filepath)

# %%
print 'Pandas version ' + pd.__version__
# Out:
# Pandas version 0.17.1

# %%
new_df = pd.read_csv('nline_data.csv',sep='\t')

# %%
new_df.catch.unique()
# Out:
# array([1, 0])

# %%
len(new_df)
# Out:
# 3648

# %%
new_df.loc[:,:]= new_df[new_df['catch']<1]
#len(nline_miss)
new_df['Missed'] = new_df['Error']
new_df.loc[new_df['Missed']<1,'Missed'] = 0
#Pick only responded trials
new_df.loc[:,:] = new_df[new_df['Missed']==0]

# %%
new_df = new_df[pd.notnull(new_df['Subject'])]

# %%
len(new_df)
# Out:
# 2590

# %%
new_df.loc[:,'AbsError'] = np.abs(new_df['Error'])

# %%
new_df['BigError'] = 0
new_df.loc[new_df['AbsError']>0.15,'BigError'] = 1
new_df['BigError'].sum()
# Out:
# 33

# %%
new_df.loc[:,'Task'] = new_df['Task'].replace([1,2,3],['N+', 'N-/+', 'Word'])

# %%
new_df.Task
# Out:
# 2       Word
# 4       Word
# 5       Word
# 6       Word
# 7       Word
# 8       Word
# 9       Word
# 10      Word
# 11      Word
# 12      Word
# 13      Word
# 16      N-/+
# 17      N-/+
# 18      N-/+
# 20      N-/+
# 21      N-/+
# 22      N-/+
# 24      N-/+
# 25      N-/+
# 26      N-/+
# 27      N-/+
# 28      N-/+
# 30      N-/+
# 33        N+
# 34        N+
# 35        N+
# 36        N+
# 37        N+
# 38        N+
# 40        N+
#         ...
# 3602    N-/+
# 3604    N-/+
# 3605    N-/+
# 3607    N-/+
# 3608    N-/+
# 3609    N-/+
# 3611    N-/+
# 3614    N-/+
# 3615    N-/+
# 3619    Word
# 3622    Word
# 3623    Word
# 3624    Word
# 3625    Word
# 3626    Word
# 3627    Word
# 3629    Word
# 3630    Word
# 3631    Word
# 3633      N+
# 3634      N+
# 3636      N+
# 3637      N+
# 3638      N+
# 3641      N+
# 3643      N+
# 3644      N+
# 3645      N+
# 3646      N+
# 3647      N+
# Name: Task, dtype: object

# %%
pal = sns.color_palette()

# %%
new_df = new_df.sort_values(by='Line_pct')

# %%
np.sort(new_df.Subject.unique())
# Out:
# array(['s_02003', 's_02004', 's_02005', 's_02006', 's_02007', 's_02010',
#        's_02011', 's_02012', 's_02014', 's_02015', 's_02016', 's_02017',
#        's_02018', 's_02019', 's_02021', 's_02022', 's_02023', 's_02024',
#        's_02027'], dtype=object)

# %%
#new_df.loc[:,:] = new_df[new_df['Subject']!='s_04116']

# %%
#df.loc[:,:] = new_df[new_df['Subject']!='s_04117']

# %%
#df.loc[:,:] = new_df[new_df['Subject']!='s_04104']

# %%
#new_df = new_df[pd.notnull(new_df['Subject'])]

# %%
len(new_df)
# Out:
# 2590

# %%
np.sort(new_df.Subject.unique())
# Out:
# array(['s_02003', 's_02004', 's_02005', 's_02006', 's_02007', 's_02010',
#        's_02011', 's_02012', 's_02014', 's_02015', 's_02016', 's_02017',
#        's_02018', 's_02019', 's_02021', 's_02022', 's_02023', 's_02024',
#        's_02027'], dtype=object)

# %%
new_df.loc[(new_df.Subject=='s_02017') & (new_df.Task=='Word')]
# Out:
#       Subject    Run  Trial  BadPress  Block  Click  Correct     Error  \
# 2611  s_02017  Run_1     19         0      2      1     0.03 -0.018987
# 2572  s_02017  Run_2     28         0      2      1     0.03 -0.012379
# 2673  s_02017  Run_0     33         0      3      1     0.07 -0.006123
# 2613  s_02017  Run_1     21         0      2      1     0.07 -0.012731
# 2502  s_02017  Run_3      6         0      1      1     0.07  0.007093
# 2566  s_02017  Run_2     22         0      2      1     0.11  0.000132
# 2622  s_02017  Run_1     30         0      2      1     0.11  0.000132
# 2683  s_02017  Run_0     43         0      3      1     0.11 -0.006476
# 2680  s_02017  Run_0     40         0      3      1     0.21 -0.000749
# 2562  s_02017  Run_2     18         0      2      1     0.21 -0.007357
# 2499  s_02017  Run_3      3         0      1      1     0.21  0.005859
# 2614  s_02017  Run_1     22         0      2      1     0.21 -0.000749
# 2610  s_02017  Run_1     18         0      2      1     0.28  0.008546
# 2569  s_02017  Run_2     25         0      2      1     0.28 -0.004670
# 2574  s_02017  Run_2     30         0      2      1     0.33 -0.001806
# 2510  s_02017  Run_3     14         0      1      1     0.33 -0.008414
# 2621  s_02017  Run_1     29         0      2      1     0.33  0.011410
# 2679  s_02017  Run_0     39         0      3      1     0.36  0.007841
# 2504  s_02017  Run_3      8         0      1      1     0.36  0.007841
# 2615  s_02017  Run_1     23         0      2      1     0.36 -0.045022
# 2564  s_02017  Run_2     20         0      2      1     0.36  0.014449
# 2506  s_02017  Run_3     10         0      1      1     0.45  0.010352
# 2619  s_02017  Run_1     27         0      2      1     0.45  0.003744
# 2672  s_02017  Run_0     32         0      3      1     0.45  0.003744
# 2505  s_02017  Run_3      9         0      1      1     0.57  0.009295
# 2612  s_02017  Run_1     20         0      2      1     0.57 -0.017137
# 2575  s_02017  Run_2     31         0      2      1     0.57  0.002687
# 2677  s_02017  Run_0     37         0      3      1     0.57  0.002687
# 2500  s_02017  Run_3      4         0      1      1     0.60  0.018943
# 2561  s_02017  Run_2     17         0      2      1     0.60 -0.007489
# 2684  s_02017  Run_0     44         0      3      1     0.60 -0.000881
# 2609  s_02017  Run_1     17         0      2      1     0.65 -0.017841
# 2570  s_02017  Run_2     26         0      2      1     0.65  0.001982
# 2678  s_02017  Run_0     38         0      3      1     0.65 -0.017841
# 2687  s_02017  Run_0     47         0      3      1     0.74  0.044141
# 2501  s_02017  Run_3      5         0      1      1     0.74 -0.002115
# 2568  s_02017  Run_2     24         0      2      1     0.74 -0.002115
# 2675  s_02017  Run_0     35         0      3      1     0.77 -0.018899
# 2508  s_02017  Run_3     12         0      1      1     0.77  0.000925
# 2560  s_02017  Run_2     16         0      2      1     0.77 -0.025507
# 2498  s_02017  Run_3      2         0      1      1     0.85 -0.006388
# 2620  s_02017  Run_1     28         0      2      1     0.85  0.006828
# 2686  s_02017  Run_0     46         0      3      1     0.85 -0.019604
# 2567  s_02017  Run_2     23         0      2      1     0.90 -0.010132
# 2507  s_02017  Run_3     11         0      1      1     0.90 -0.010132
#
#       ITI_onset  ITI_onset_real    ...     decision_onset  \
# 2611      245.0      245.002045    ...              254.5
# 2572      357.5      357.504425    ...              363.5
# 2673      420.0      420.001927    ...              426.5
# 2613      268.0      268.003022    ...              277.0
# 2502       82.0       82.001210    ...               92.0
# 2566      285.0      285.002917    ...              295.0
# 2622      377.5      377.501555    ...              389.5
# 2683      538.5      538.514714    ...              547.5
# 2680      498.0      498.001366    ...              508.5
# 2562      239.0      239.000648    ...              246.0
# 2499       46.5       46.501572    ...               56.0
# 2614      280.0      280.003355    ...              287.5
# 2610      235.0      235.003696    ...              242.0
# 2569      322.5      322.501600    ...              331.5
# 2574      382.0      382.005573    ...              389.5
# 2510      184.5      184.505692    ...              192.5
# 2621      363.5      363.501389    ...              374.5
# 2679      487.5      487.501258    ...              495.0
# 2504      109.5      109.502211    ...              117.5
# 2615      290.5      290.502373    ...              297.5
# 2564      261.0      261.002217    ...              268.5
# 2506      133.5      133.501871    ...              141.5
# 2619      338.5      338.512106    ...              347.0
# 2672      410.0      410.077241    ...              417.0
# 2505      120.5      120.501984    ...              130.5
# 2612      257.5      257.503341    ...              265.0
# 2575      392.5      392.501397    ...              401.0
# 2677      467.0      467.011211    ...              473.5
# 2500       59.0       59.001482    ...               68.0
# 2561      226.0      226.001739    ...              236.0
# 2684      550.5      550.502334    ...              561.0
# 2609      223.0      223.010811    ...              232.0
# 2570      334.5      334.500875    ...              343.5
# 2678      476.5      476.503072    ...              484.5
# 2687      591.0      591.004103    ...              599.0
# 2501       71.0       71.001289    ...               79.0
# 2568      310.0      310.000742    ...              319.5
# 2675      440.5      440.510910    ...              450.5
# 2508      157.5      157.501883    ...              168.5
# 2560      212.0      212.066230    ...              223.0
# 2498       35.5       35.502998    ...               43.5
# 2620      350.0      350.002272    ...              360.5
# 2686      576.0      576.015739    ...              588.0
# 2567      298.0      298.001266    ...              307.0
# 2507      144.5      144.501882    ...              154.5
#
#       decision_onset_real  hold hold_onset  hold_onset_real  iti  mouse_pos  \
# 2611           254.507126   5.0      249.5       249.503099  4.0        0.5
# 2572           363.502560   2.5      361.0       361.001582  3.0        0.5
# 2673           426.505786   2.5      424.0       424.001517  3.5        0.5
# 2613           277.007884   5.5      271.5       271.501805  3.0        0.5
# 2502            92.015900   6.5       85.5        85.502543  3.0        0.5
# 2566           295.000679   4.0      291.0       291.002648  5.5        0.5
# 2622           389.510865   4.5      385.0       385.002075  7.0        0.5
# 2683           547.509151   4.0      543.5       543.503385  4.5        0.5
# 2680           508.508360   4.5      504.0       504.003870  5.5        0.5
# 2562           246.049250   3.0      243.0       243.001964  3.5        0.5
# 2499            56.014914   2.5       53.5        53.501490  6.5        0.5
# 2614           287.507977   2.5      285.0       285.001881  4.5        0.5
# 2610           242.011132   3.0      239.0       239.002908  3.5        0.5
# 2569           331.501741   3.5      328.0       328.002301  5.0        0.5
# 2574           389.503219   3.0      386.5       386.501893  4.0        0.5
# 2510           192.502079   3.5      189.0       189.001616  4.0        0.5
# 2621           374.510560   6.5      368.0       368.002218  4.0        0.5
# 2679           495.007973   3.0      492.0       492.003617  4.0        0.5
# 2504           117.516639   3.0      114.5       114.502114  4.5        0.5
# 2615           297.508406   3.5      294.0       294.003482  3.0        0.5
# 2564           268.516639   3.5      265.0       265.002062  3.5        0.5
# 2506           141.500805   3.0      138.5       138.501486  4.5        0.5
# 2619           347.009712   3.5      343.5       343.501727  4.5        0.5
# 2672           417.005486   3.5      413.5       413.503535  3.0        0.5
# 2505           130.500462   3.5      127.0       127.001276  6.0        0.5
# 2612           265.007403   3.5      261.5       261.503375  3.5        0.5
# 2575           401.003675   4.5      396.5       396.502517  3.5        0.5
# 2677           473.509882   3.0      470.5       470.503247  3.0        0.5
# 2500            68.015333   4.5       63.5        63.502671  4.0        0.5
# 2561           236.015717   5.5      230.5       230.502405  4.0        0.5
# 2684           561.009810   5.5      555.5       555.503037  4.5        0.5
# 2609           232.012490   4.0      228.0       228.001971  4.5        0.5
# 2570           343.502035   2.5      341.0       341.001603  6.0        0.5
# 2678           484.507619   4.0      480.5       480.503175  3.5        0.5
# 2687           599.010877   3.5      595.5       595.501820  4.0        0.5
# 2501            79.015699   4.0       75.0        75.002448  3.5        0.5
# 2568           319.501525   6.0      313.5       313.501545  3.0        0.5
# 2675           450.506575   5.0      445.5       445.502304  4.5        0.5
# 2508           168.501194   5.0      163.5       163.502533  5.5        0.5
# 2560           223.015528   6.5      216.5       216.502412  4.0        0.5
# 2498            43.514551   3.0       40.5        40.502061  4.5        0.5
# 2620           360.509969   4.0      356.5       356.501612  6.0        0.5
# 2686           588.010420   6.5      581.5       581.503577  5.0        0.5
# 2567           307.001045   4.0      303.0       303.002256  4.5        0.5
# 2507           154.501082   5.5      149.0       149.002165  4.0        0.5
#
#       Missed  AbsError  BigError
# 2611       0  0.018987         0
# 2572       0  0.012379         0
# 2673       0  0.006123         0
# 2613       0  0.012731         0
# 2502       0  0.007093         0
# 2566       0  0.000132         0
# 2622       0  0.000132         0
# 2683       0  0.006476         0
# 2680       0  0.000749         0
# 2562       0  0.007357         0
# 2499       0  0.005859         0
# 2614       0  0.000749         0
# 2610       0  0.008546         0
# 2569       0  0.004670         0
# 2574       0  0.001806         0
# 2510       0  0.008414         0
# 2621       0  0.011410         0
# 2679       0  0.007841         0
# 2504       0  0.007841         0
# 2615       0  0.045022         0
# 2564       0  0.014449         0
# 2506       0  0.010352         0
# 2619       0  0.003744         0
# 2672       0  0.003744         0
# 2505       0  0.009295         0
# 2612       0  0.017137         0
# 2575       0  0.002687         0
# 2677       0  0.002687         0
# 2500       0  0.018943         0
# 2561       0  0.007489         0
# 2684       0  0.000881         0
# 2609       0  0.017841         0
# 2570       0  0.001982         0
# 2678       0  0.017841         0
# 2687       0  0.044141         0
# 2501       0  0.002115         0
# 2568       0  0.002115         0
# 2675       0  0.018899         0
# 2508       0  0.000925         0
# 2560       0  0.025507         0
# 2498       0  0.006388         0
# 2620       0  0.006828         0
# 2686       0  0.019604         0
# 2567       0  0.010132         0
# 2507       0  0.010132         0
#
# [45 rows x 38 columns]

# %%
plt_df = new_df.copy()
plt_df = plt_df.groupby(['Task','Line_pct','Subject']).mean()
plt_df.to_csv('plot_data.csv', sep='\t')
plt_df = pd.read_csv('plot_data.csv',sep='\t')

# %% [markdown]
# ## RT boxplots

# %%
ax = sns.factorplot(x='Line_pct',y='RT',hue='Task',row='Task',
                    data=plt_df,kind='box',size=4,aspect=3)
sns.despine(trim=True)

# %%
plt.figure(figsize=(14,6))
for key,grp in plt_df.groupby('Task'):
    print 
    plt.plot(grp.Line_pct.unique(),grp.groupby('Line_pct')['RT'].mean(),'-o',label=key)
plt.legend(loc = 'best')
plt.ylim([1.4,2.6])
plt.xlabel('Line_pct')
plt.ylabel('Mean RT')
sns.despine(trim=True)

# %%
g = sns.FacetGrid(plt_df, row='Task', hue='Task',palette=pal,size=4,aspect=3)
g = g.map(sns.regplot, 'Line_pct', 'RT', fit_reg=False,x_estimator=np.mean).set(xlim=(0,1))
sns.despine(trim=True)
# Out:
# /Users/frankanayet/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
tmp = [{'Task':'Word','Line_pct':0.98,'Subject':'s_02017'}]
tmp_df = pd.DataFrame(tmp)

# %%
plt_df = plt_df.append(tmp_df, ignore_index=True)
plt_df.loc[(plt_df.Subject=='s_02017')&(plt_df.Task=='Word'),['Subject', 'Task', 'Line_pct', 'RT']]
# Out:
#      Subject  Task  Line_pct        RT
# 619  s_02017  Word      0.03  2.294169
# 638  s_02017  Word      0.07  2.331174
# 657  s_02017  Word      0.11  2.418349
# 676  s_02017  Word      0.21  2.110831
# 695  s_02017  Word      0.28  1.924134
# 714  s_02017  Word      0.33  2.133071
# 733  s_02017  Word      0.36  2.077659
# 752  s_02017  Word      0.45  2.163213
# 771  s_02017  Word      0.57  2.026353
# 790  s_02017  Word      0.60  1.993727
# 809  s_02017  Word      0.65  2.077921
# 828  s_02017  Word      0.74  2.070663
# 847  s_02017  Word      0.77  2.407192
# 866  s_02017  Word      0.85  2.521825
# 885  s_02017  Word      0.90  2.135966
# 911  s_02017  Word      0.98       NaN

# %%
len(plt_df.loc[plt_df['Task']=='N+','RT'].get_values() - plt_df.loc[plt_df['Task']=='Word','RT'].get_values())
# Out:
# 304

# %% [markdown]
# Subtraction is being calculated as 1. Take mean for each subject on each position(3 values),then subtract from each (subject,value) pair in the N+ task the value from the same (subject,value) pair in the word task. Then take the median of the result.

# %%
plt_df.sort(['Task','Line_pct','Subject'],inplace=True)
# Out:
# /Users/frankanayet/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
plt_df.loc[plt_df['Task']=='N+','RT-'] = plt_df.loc[plt_df['Task']=='N+','RT'].get_values() - plt_df.loc[plt_df['Task']=='Word','RT'].get_values()

# %%
plt_df.loc[plt_df['Task']=='N-/+','RT-'] = plt_df.loc[plt_df['Task']=='N-/+','RT'].get_values() - plt_df.loc[plt_df['Task']=='Word','RT'].get_values()

# %%
plt_df.columns
# Out:
# Index([u'AbsError', u'BadPress', u'BigError', u'Block', u'Click', u'Correct',
#        u'Error', u'ITI_onset', u'ITI_onset_real', u'Line_pct', u'Missed',
#        u'Move', u'Points', u'RT', u'RTHold', u'Response', u'Slow', u'Subject',
#        u'Task', u'TestX', u'Trial', u'Trial.1', u'Wrong', u'catch',
#        u'consider_onset', u'consider_onset_real', u'decision_end',
#        u'decision_end_real', u'decision_onset', u'decision_onset_real',
#        u'hold', u'hold_onset', u'hold_onset_real', u'iti', u'mouse_pos',
#        u'RT-'],
#       dtype='object')

# %%
ax = sns.pointplot(x=plt_df.loc[plt_df['Task']=='N+','Line_pct'],
                   y=plt_df.loc[plt_df['Task']=='N+','RT-'],
                   estimator=np.mean,size=4,aspect=3)
plt.axhline(y=0, color='black')
plt.title('N+ Task Minus Word Task', y=1.03)
sns.despine(trim=True)
plt.tight_layout()

# %%
ax = sns.pointplot(x=plt_df.loc[plt_df['Task']=='N-/+','Line_pct'],
                   y=plt_df.loc[plt_df['Task']=='N-/+','RT-'],
                   estimator=np.mean,size=4,aspect=3,color=pal[1])
plt.axhline(y=0, color='black')
plt.title('N-/+ Task Minus Word Task',y=1.03)
sns.despine(trim=True)
plt.tight_layout()

# %% [markdown]
# # MAE boxplots

# %% [markdown]
# With means for each subject

# %% [markdown]
# ## Remove Big Errors

# %%
plt_df = new_df.copy()

# %%
len(plt_df)
# Out:
# 2590

# %%
plt_df = plt_df[plt_df['BigError']==0]

# %%
len(plt_df)
# Out:
# 2557

# %%
plt_df.BigError.unique()
# Out:
# array([0])

# %%
plt_df = plt_df.groupby(['Task','Line_pct','Subject']).mean()
plt_df.to_csv('plot_data.csv', sep='\t')
plt_df = pd.read_csv('plot_data.csv',sep='\t')

# %%
ax = sns.factorplot(x='Line_pct',y='AbsError',hue='Task',row='Task',
                    data=plt_df,kind='box',size=4,aspect=3,sharey=True)
sns.despine(trim=True)

# %%
plt.figure(figsize=(14,6))
for key,grp in plt_df.groupby('Task'):
    print 
    plt.plot(grp.Line_pct.unique(),grp.groupby('Line_pct')['AbsError'].mean(),'-o',label=key)
plt.legend(loc = 'best')
plt.ylim([0,0.06])
plt.xlabel('Line_pct')
plt.ylabel('Absolute Error')
sns.despine(trim=True)

# %%
g = sns.FacetGrid(plt_df, row='Task',hue='Task',palette=pal,size=4,aspect=3)
g = g.map(sns.regplot, 'Line_pct', 'AbsError', fit_reg=False,x_estimator=np.mean).set(xlim=(0,1))
sns.despine(trim=True)

# %% [markdown]
# ## Signed Error boxplot

# %%
ax = sns.factorplot(x='Line_pct',y='Error',hue='Task',row='Task',
                    data=plt_df,kind='box',size=4,aspect=3,sharey=True)
sns.despine(trim=True)
ax.map(plt.axhline, y=0, color='black')

# %%
plt.figure(figsize=(14,6))
for key,grp in plt_df.groupby('Task'):
    print 
    plt.plot(grp.Line_pct.unique(),grp.groupby('Line_pct')['Error'].mean(),'-o',label=key)
plt.axhline(y=0,color='black')
plt.legend(loc = 'best')
plt.ylim([-.06,0.06])
plt.xlabel('Line_pct')
plt.ylabel('Signed Error')
sns.despine(trim=True)

# %%
g = sns.FacetGrid(plt_df, row='Task',hue='Task',palette=pal,size=4,aspect=3)
g = g.map(sns.regplot, 'Line_pct', 'Error', fit_reg=False,x_estimator=np.mean).set(xlim=(0,1))
sns.despine(trim=True)
for ax in g.axes.flat:
    ax.plot((0,1),(0,0),c='black')

# %% [markdown]
# ## SD boxplot

# %%
sd_df = new_df.copy()

# %%
sd_df = sd_df[sd_df['BigError']==0]

# %%
len(sd_df)
# Out:
# 2557

# %%
sd_df = sd_df.groupby(['Task','Line_pct','Subject']).std()

# %%
sd_df.to_csv('plot_data_SD.csv', sep='\t')
sd_df = pd.read_csv('plot_data_SD.csv',sep='\t')

# %%
ax = sns.factorplot(x='Line_pct',y='Error',hue='Task',row='Task',data=sd_df,
                    kind='box',size=4,aspect=3,sharey=True)
sns.despine(trim=True)
(ax.set_axis_labels("Line_pct",'SD'))

# %%
g = sns.FacetGrid(sd_df,hue='Task', row= 'Task', palette=pal,size=4,aspect=3)
g = g.map(sns.regplot, 'Line_pct', 'Error', fit_reg=False,x_estimator=np.mean).set(xlim=(0,1))
sns.despine(trim=True)
(ax.set_axis_labels("Line_pct",'SD'))

# %%
plt.figure(figsize=(14,6))
for key,grp in sd_df.groupby('Task'):
    print 
    plt.plot(grp.Line_pct.unique(),grp.groupby('Line_pct')['Error'].mean(),'-o',label=key)
plt.axhline(y=0,color='black')
plt.legend(loc = 'best')
plt.ylim([0,0.04])
plt.xlabel('Line_pct')
plt.ylabel('SD')
sns.despine(trim=True)

# %% [markdown]
# ## SD vs Median placement instead of Correct Placement

# %%
median_scores = plt_df.groupby(['Task', 'Line_pct'])['Response'].median()

# %%
median_scores
# Out:
# Task  Line_pct
# N+    0.03        0.020558
#       0.07        0.087004
#       0.11        0.105727
#       0.21        0.219163
#       0.28        0.262115
#       0.33        0.325991
#       0.36        0.317181
#       0.45        0.442731
#       0.57        0.572687
#       0.60        0.602423
#       0.65        0.636564
#       0.74        0.751101
#       0.77        0.773128
#       0.85        0.850220
#       0.90        0.887665
#       0.98        0.991924
# N-/+  0.03        0.041850
#       0.07        0.110132
#       0.11        0.147577
#       0.21        0.253304
#       0.28        0.286344
#       0.33        0.354626
#       0.36        0.361233
#       0.45        0.433921
#       0.57        0.579295
#       0.60        0.607930
#       0.65        0.645374
#       0.74        0.735683
#       0.77        0.744493
#       0.85        0.817181
#       0.90        0.863436
#       0.98        0.973568
# Word  0.03        0.026432
#       0.07        0.072687
#       0.11        0.110132
#       0.21        0.211454
#       0.28        0.279736
#       0.33        0.328194
#       0.36        0.359031
#       0.45        0.447137
#       0.57        0.570485
#       0.60        0.596916
#       0.65        0.647577
#       0.74        0.735683
#       0.77        0.764317
#       0.85        0.843612
#       0.90        0.893172
#       0.98        0.982379
# Name: Response, dtype: float64

# %%
sd_medians = {}
for key,grp in sd_df.groupby('Task'):
    sd_medians[key] = grp.groupby('Line_pct')['Error'].median()

# %%
sd_medians['N+']
# Out:
# Line_pct
# 0.03    0.011965
# 0.07    0.014018
# 0.11    0.020983
# 0.21    0.023206
# 0.28    0.026432
# 0.33    0.028035
# 0.36    0.028419
# 0.45    0.019075
# 0.57    0.013216
# 0.60    0.016630
# 0.65    0.020188
# 0.74    0.020188
# 0.77    0.036394
# 0.85    0.029158
# 0.90    0.026706
# 0.98    0.006358
# Name: Error, dtype: float64

# %%
fig = plt.figure(figsize=(12,12))
fig1 = plt.subplot(3,1,1)
fig1.plot(median_scores['N+'], sd_medians['N+'], 'o-', color=pal[0])
plt.title('SD Signed Error By Position N+')
plt.xlabel('Line position in % N+', labelpad = 4)
plt.ylabel('SD')
plt.ylim([0,0.04])
plt.yticks(([0.02,0.04]))

fig2 = plt.subplot(3,1,2)
fig2.plot(median_scores['N-/+'], sd_medians['N-/+'], color=pal[1], marker='s')
plt.title('SD Signed Error By Position N+/-')
plt.xlabel('Line position in % N-/+', labelpad = 4)
plt.ylabel('SD')
plt.ylim([0,0.04])
plt.yticks(([0.02,0.04]))

fig3 = plt.subplot(3,1,3)
fig3.plot(median_scores['N-/+'], sd_medians['Word'], color=pal[2], marker='p')
plt.title('SD Signed Error By Position Word')
plt.xlabel('Line position in % Word', labelpad = 4)
plt.ylabel('SD')
plt.ylim([0,0.04])
plt.yticks(([0.02,0.04]))

plt.subplots_adjust(hspace=.4)

# %%
plt.figure(figsize=(14,6))
for key,grp in sd_df.groupby('Task'):
    print 
    plt.plot(grp.Line_pct.unique(),grp.groupby('Line_pct')['Error'].mean(),'-o',label=key)
plt.axhline(y=0,color='black')
plt.legend(loc = 'best')
plt.ylim([0,0.04])
plt.xlabel('Line_pct')
plt.ylabel('SD')
sns.despine(trim=True)

# %%
plt.figure(figsize=(14,6))
for key,grp in sd_df.groupby('Task'):
    print 
    plt.plot(median_scores[key],grp.groupby('Line_pct')['Error'].mean(),'-o',label=key)
plt.axhline(y=0,color='black')
plt.legend(loc = 'best')
plt.ylim([0,0.04])
plt.xlabel('Line_pct')
plt.ylabel('SD')
sns.despine(trim=True)

# %% [markdown]
# ## Landmark Vs. MAE

# %%
plt_df.loc[:,'dist0'] = plt_df.Line_pct

# %%
plt_df.loc[:,'dist50'] = abs(plt_df.dist0 - 0.5)

# %%
plt_df.loc[:,'dist100'] = abs(plt_df.dist0 - 1)

# %%
plt_df.loc[:,'distLand'] = plt_df[['dist0','dist50','dist100']].min(1)

# %%
g = sns.lmplot(x='distLand',y='AbsError',hue='Task',row='Task',data=plt_df,size=4,aspect=3)

# %% [markdown]
# This is the same result as the other notebook but shows the difference in size of outliers to central tendency as reflected by the median calculated at each landmark distance.

# %% [markdown]
# ## Landmark distance Vs signed error

# %%
g = sns.lmplot(x='distLand',y='Error',hue='Task',row='Task',data=plt_df,size=4,aspect=3)

# %% [markdown]
# ## Math Score and MAE

# %%
math = pd.read_csv('Math_Results.csv')

# %%
plt_df = pd.merge(plt_df,math,on='Subject',how='inner')

# %%
sat_df = plt_df.groupby(['Task', 'Subject']).mean()

# %%
sat_df.to_csv('plot_data_SAT.csv', sep='\t')
sat_df = pd.read_csv('plot_data_SAT.csv',sep='\t')

# %%
g = sns.lmplot(x='AbsError',y='Math_Score',hue='Task',row='Task',data=sat_df,
               size=4,aspect=3,sharex=False,truncate=True)

# %%
plt.figure(figsize=(14,6))
for key,grp in sat_df.groupby('Task'):
    plt.plot(grp.AbsError,grp.Math_Score,'o',label=key)
plt.legend(loc = 'best')
plt.ylim([0,20])
plt.xlabel('Absolute Error')
plt.ylabel('Math Score')
sns.despine(trim=True)

# %% [markdown]
# ## Signed Error vs SAT

# %%
g = sns.lmplot(x='Error',y='Math_Score',hue='Task',row='Task',data=sat_df,
               size=4,aspect=3,sharex=False,truncate=True)

# %%
plt.figure(figsize=(14,6))
for key,grp in sat_df.groupby('Task'):
    plt.plot(grp.Error,grp.Math_Score,'o',label=key)
plt.legend(loc = 'best')
plt.ylim([0,20])
plt.xlabel('Signed Error')
plt.ylabel('Math Score')
sns.despine(trim=True)
