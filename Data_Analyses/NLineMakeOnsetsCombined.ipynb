# %%
#Opened with --pylab flag
#Need to create code to analyze piot data
import pandas as pd
import numpy as np
from scipy import io
import os
import glob

# %%
## Laptop
#filepath = '/Users/frankkanayet/Dropbox/NLineExperiment/PilotData'
#filepath = '/Users/frankkanayet/Dropbox/NLineExperiment/PilotData/test3s'
filepath = '/Users/frankkanayet/Google Drive/NLineData/Beh_Data'

## Desktop
#filepath = '/Users/frankanayet/Dropbox/NLineExperiment/Data'
os.chdir(filepath)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-3611c4d8a736> in <module>()
#       6 ## Desktop
#       7 #filepath = '/Users/frankanayet/Dropbox/NLineExperiment/Data'
# ----> 8 os.chdir(filepath)
#
# OSError: [Errno 2] No such file or directory: '/Users/frankkanayet/Google Drive/NLineData/Beh_Data'

# %%
#print 'Pandas version ' + pd.__version__

# %%
filenames = glob.glob('Nline_*.mat')
print filenames
#index to isolate subj numbers
data_dict = {}
for i in filenames:
    id1 = filenames[0].find('_') + 1
    id2 = filenames[0].find('-')
    sub_nbr = i[id1:id2]
    sub_name = i
    s_id = 's_'+sub_nbr
    data_dict[s_id] = io.loadmat(sub_name)

#sub_name = filenames[0] #This will be changed to a loop for all subjects later
#mat = io.loadmat(sub_name)
data_dict.keys()

# %%
sub_ex = data_dict.keys()[0]

# %%
#data_dict['s_00011']['p']

# %%
#for i in data_dict:
#    data_dict[i].pop('__header__')
#    data_dict[i].pop('__version__')
#    data_dict[i].pop('__globals__')
#data_dict['s_00011'].keys()

# %%
## The indexes of zeros are as follows [0][0][x][y][z][0] The x y z are the 3 dimensions of the data 3d matrix the zeros are padding
data_dict[sub_ex]['p']['NlineResults'][0][0][0][5][0][0]
len(data_dict[sub_ex]['p']['NlineResults'][0][0][:])

# %%
data_dict[sub_ex]['p'].dtype.names

# %%
cons_time = data_dict[sub_ex]['p']['consider'][0][0][0][0]
dec_time = data_dict[sub_ex]['p']['decision'][0][0][0][0]

# %%
new_dat = {}
#new_df = {}
for s in data_dict:
    tasks = ['NlineResults']
    new_dat[s]={}
    #new_df[s] = {}
    for task in tasks:
        dat = data_dict[s]['p'][task]
        num_fields = len(data_dict[s]['p'][task][0][0][0])
        dat_names = []
        for k in range(0,num_fields):
            dat_names.append(dat[0][0][0][k][0][0])
        new_dat[s][task] = {}
        runs = data_dict[s]['p']['runs'][0][0][0][0]
        for run in range(0,runs):
            run_name = 'Run_'+str(run)
            new_dat[s][task][run_name] = {}
            for i in range(0,len(dat_names)):
                new_dat[s][task][run_name][dat_names[i]] = []
                for j in range(0,len(dat[0][0][:])-1):
                    if dat_names[i] == 'catch_probe':
                        new_dat[s][task][run_name][dat_names[i]].append(dat[0][0][j+1][i][run])
                    elif dat_names[i] == 'Probe':
                        new_dat[s][task][run_name][dat_names[i]].append(dat[0][0][j+1][i][run][0])
                    else:
                        new_dat[s][task][run_name][dat_names[i]].append(dat[0][0][j+1][i][run][0][0])
#legible access to the data
Nline = 'NlineResults' #numberline

# %%
new_dat[sub_ex]['NlineResults']['Run_1'].keys()

# %%
new_dat[sub_ex]['NlineResults']['Run_1']['Probe']

# %%
new_dat[sub_ex]['NlineResults']['Run_1']['catch_probe']

# %%
subj = data_dict.keys()
tasks = [Nline]
tuples = []
rows = len(data_dict[sub_ex]['p'][Nline][0][0][:])-1
for s in subj:
    runs = new_dat[s]['NlineResults'].keys()
    for run in runs:
        for i in range(0,rows):
            tuples.append((s, run, i))
len(tuples)
#iterables = [subj,tasks,runs]
indexes = pd.MultiIndex.from_tuples(tuples, names=['Subj', 'Run', 'Trial'])
nline_cols = len(new_dat[sub_ex][Nline]['Run_0'].keys())

# %%
indexes[90]

# %%
indexes[1][1]

# %%
varnames = new_dat[sub_ex][Nline]['Run_0'].keys()
varnames[24]

# %%
len(indexes)

# %%
# Code empty cells of probes and catch_probes as Nan
Dic_list = []
probes = ['catch_probe']
for data in indexes:
    temp_dict = {}
    for var in varnames:
        if var == probes[0]:
            if len(new_dat.get(data[0]).get(Nline).get(data[1]).get(var)[data[2]]) == 0:
                new_dat.get(data[0]).get(Nline).get(data[1]).get(var)[data[2]] = np.array([np.nan])
            temp_dict[var] = new_dat.get(data[0]).get(Nline).get(data[1]).get(var)[data[2]][0]
        else:
            temp_dict[var] = new_dat.get(data[0]).get(Nline).get(data[1]).get(var)[data[2]]
    Dic_list.append(temp_dict)

# %%
#Create dataframe
nline_df = pd.DataFrame(Dic_list, index=indexes)
sum(nline_df.loc[sub_ex].loc['Run_0'].iloc[0:48]['catch'])

# %%
nline_df.loc[sub_ex].loc['Run_0'].iloc[0:10]['Error']

# %%
nline_df.index.names = ['Subject', 'Run', 'Trial']
nline_df.index.names

# %%
test = nline_df['Probe']
for i in range(0,len(test)):
    test[i] = np.ravel(test[i])
    test[i] = test[i][0]
nline_df['Probe'] = test
nline_df['Probe']

# %% [markdown]
# ### Create Stim Labels

# %%
#now nline
#nline_df['Num'] = nline_df['Num'].map('{:.0f}'.format)
#nline_df['Denom'] = nline_df['Denom'].map('{:.0f}'.format)
#nline_df['Stim'] = nline_df['Num']+'/'+nline_df['Denom']
#nline_df['Stim']

# %%
nline_df.columns
# Out:
# Index([u'BadPress', u'Block', u'Click', u'Correct', u'Error', u'ITI_onset', u'ITI_onset_real', u'Line_pct', u'Move', u'Points', u'Probe', u'RT', u'RTHold', u'Response', u'Slow', u'Task', u'TestX', u'Trial', u'Wrong', u'catch', u'catch_probe', u'consider_onset', u'consider_onset_real', u'decision_end', u'decision_end_real', u'decision_onset', u'decision_onset_real', u'hold', u'hold_onset', u'hold_onset_real', u'iti', u'mouse_pos'], dtype='object')

# %%
nline_df['Task']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c90e4e9e2c92> in <module>()
# ----> 1 nline_df['Task']
#
# NameError: name 'nline_df' is not defined

# %% [markdown]
# # Make Onsets

# %% [markdown]
# # Number Line Analyses

# %% [markdown]
# ### Accuracy & RT

# %%
nline_df['catch'].sum()
# Out:
# 432

# %%
nline_no_miss = nline_df[['Error', 'RT', 'RTHold', 'catch']]
nline_no_miss = nline_no_miss[nline_no_miss['catch']<1]
len(nline_no_miss)
# Out:
# 1296

# %%
nline_no_miss = nline_no_miss.replace(-1, np.nan)
nline_no_miss.pop('catch')
# Out:
# Subject  Run    Trial
# s_02009  Run_3  1        0
#                 2        0
#                 3        0
#                 5        0
#                 6        0
#                 7        0
#                 8        0
#                 9        0
#                 11       0
#                 12       0
#                 13       0
#                 15       0
#                 17       0
#                 18       0
#                 19       0
# ...
# s_02011  Run_0  27       0
#                 28       0
#                 30       0
#                 32       0
#                 35       0
#                 36       0
#                 37       0
#                 38       0
#                 39       0
#                 40       0
#                 41       0
#                 42       0
#                 43       0
#                 44       0
#                 47       0
# Name: catch, Length: 1296, dtype: int64

# %%
nline_no_miss['Missed'] = nline_no_miss['Error']
nline_no_miss['Missed'][nline_no_miss['Missed']<1] = 0
nline_missed = nline_no_miss['Missed']
nline_missed
# Out:
# Subject  Run    Trial
# s_02009  Run_3  1        0
#                 2        0
#                 3        0
#                 5        0
#                 6        0
#                 7        0
#                 8        0
#                 9        0
#                 11       0
#                 12       0
#                 13       0
#                 15       0
#                 17       0
#                 18       0
#                 19       0
# ...
# s_02011  Run_0  27       0
#                 28       0
#                 30       0
#                 32       1
#                 35       0
#                 36       0
#                 37       0
#                 38       0
#                 39       0
#                 40       0
#                 41       0
#                 42       0
#                 43       0
#                 44       0
#                 47       1
# Name: Missed, Length: 1296, dtype: float64

# %%
nline_no_miss = nline_no_miss[nline_no_miss['Error']<1]
nline_no_miss['Error'] = np.abs(nline_no_miss['Error'])
nline_no_miss
# Out:
#                         Error        RT    RTHold  Missed
# Subject Run   Trial
# s_02009 Run_3 1      0.056388  2.325869  0.462052       0
#               2      0.009471  2.011655  0.648239       0
#               3      0.017137  2.045767  0.502666       0
#               5      0.012731  2.794526  0.526923       0
#               6      0.032115  1.928430  0.448109       0
#               7      0.000837  2.646016  0.498345       0
#               8      0.019075  2.011882  0.542642       0
#               9      0.024449  2.176008  0.732567       0
#               11     0.052643  2.495735  0.586613       0
#               12     0.039780  2.842913  0.597258       0
#               13     0.032159  1.942424  0.449394       0
#               15     0.020000  1.725692  0.454650       0
#               17     0.006123  2.028588  0.536987       0
#               18     0.008590  1.894971  0.380307       0
#               19     0.025595  2.428051  0.458853       0
#               20     0.014449  2.176045  0.469045       0
#               21     0.003744  1.611656  0.396948       0
#               22     0.003921  1.943663  0.383196       0
#               24     0.001806  2.662367  0.556490       0
#               26     0.000881  2.442966  0.551099       0
#               27     0.000749  2.343055  0.548913       0
#               29     0.009692  2.576140  0.594083       0
#               30     0.024493  2.159518  0.453022       0
#               31     0.006388  2.661703  0.555826       0
#               32     0.002115  2.061149  0.470935       0
#               34     0.022907  2.309477  0.367291       0
#               35     0.018899  2.342407  0.519901       0
#               37     0.020000  1.761958  0.342875       0
#               38     0.030000  1.895479  0.322675       0
#               39     0.011278  2.845445  0.674254       0
# ...                       ...       ...       ...     ...
# s_02011 Run_0 2      0.037841  2.411893  0.520522       0
#               3      0.027665  2.445086  0.671212       0
#               4      0.004626  2.459315  0.482592       0
#               5      0.085683  2.743009  0.629330       0
#               6      0.032291  2.559161  0.608623       0
#               8      0.068943  2.742358  0.742034       0
#               10     0.015154  2.345311  0.688266       0
#               13     0.078370  2.708954  1.288470       0
#               14     0.035727  1.994472  0.643523       0
#               15     0.082819  2.312302  0.527254       0
#               17     0.002379  2.808612  0.568785       0
#               18     0.012335  2.059484  0.428255       0
#               19     0.004802  2.045233  0.519361       0
#               20     0.028414  2.179456  0.623719       0
#               22     0.006388  2.525986  0.497799       0
#               23     0.020749  2.662624  0.682748       0
#               24     0.025595  2.696228  0.526577       0
#               27     0.011101  2.661476  0.456263       0
#               28     0.007357  2.745879  0.598893       0
#               30     0.003744  2.228673  0.448477       0
#               35     0.035903  1.912539  0.406209       0
#               36     0.037841  2.595622  0.701872       0
#               37     0.068018  2.494690  0.673230       0
#               38     0.054978  2.728478  0.873799       0
#               39     0.008590  2.073084  0.561718       0
#               40     0.086388  2.595651  0.781628       0
#               41     0.015903  1.979101  0.489183       0
#               42     0.072467  2.562353  0.595087       0
#               43     0.019956  2.909376  0.633590       0
#               44     0.001233  2.509307  0.616248       0
#
# [1248 rows x 4 columns]

# %% [markdown]
# #### How many trials missed?

# %%
nline_missed_subj = nline_missed.groupby(level=0)
nline_missed_subj.sum()
# Out:
# Subject
# s_02001     1
# s_02002     2
# s_02003     7
# s_02004     3
# s_02005    17
# s_02006     2
# s_02007     1
# s_02009     1
# s_02010     7
# s_02011     7
# Name: Missed, dtype: float64

# %%
nline_no_miss_subj = nline_no_miss.groupby(level=0)
nline_no_miss_subj.mean()
# Out:
#             Error        RT    RTHold  Missed
# Subject
# s_02001  0.024830  2.154253  0.380134       0
# s_02002  0.037568  2.000478  0.426307       0
# s_02003  0.022472  2.240014  0.480898       0
# s_02004  0.020997  2.181841  0.390107       0
# s_02005  0.021902  2.378822  0.468106       0
# s_02006  0.026771  1.970216  0.422093       0
# s_02007  0.027687  2.117213  0.430258       0
# s_02009  0.019800  2.240575  0.499304       0
# s_02010  0.034298  1.801020  0.402272       0
# s_02011  0.031181  2.177101  0.512704       0

# %%
np.mean(nline_no_miss_subj.mean())
# Out:
# Error     0.026751
# RT        2.126153
# RTHold    0.441218
# Missed    0.000000
# dtype: float64

# %%
nline_no_miss_subj.std()
# Out:
#             Error        RT    RTHold  Missed
# Subject
# s_02001  0.031065  0.390818  0.055008       0
# s_02002  0.104379  0.337475  0.060399       0
# s_02003  0.022780  0.366943  0.082894       0
# s_02004  0.022400  0.325082  0.097012       0
# s_02005  0.032262  0.317196  0.092952       0
# s_02006  0.041957  0.345187  0.135683       0
# s_02007  0.082710  0.252646  0.106627       0
# s_02009  0.022590  0.332101  0.105460       0
# s_02010  0.044786  0.358041  0.100827       0
# s_02011  0.028585  0.320319  0.120519       0

# %%
np.mean(nline_no_miss_subj.std())
# Out:
# Error     0.043351
# RT        0.334581
# RTHold    0.095738
# Missed    0.000000
# dtype: float64

# %% [markdown]
# How many trials did they actually respond?

# %%
nline_no_miss_subj.count()
# Out:
#          Error   RT  RTHold  Missed
# Subject
# s_02001     71   71      71      71
# s_02002     70   70      70      70
# s_02003    137  137     137     137
# s_02004    141  141     141     141
# s_02005    127  127     127     127
# s_02006    142  142     142     142
# s_02007    143  143     143     143
# s_02009    143  143     143     143
# s_02010    137  137     137     137
# s_02011    137  137     137     137

# %% [markdown]
# # RT Histograms

# %%
pd.options.display.mpl_style = 'default'
nline_no_miss['RT'].hist(bins=30, range=[0,3])
pylab.ylim([0,200])
pylab.title('Number Line')
pylab.xlabel('Seconds', labelpad = 18)
pylab.ylabel('Frequency', labelpad = 18)

# %% [markdown]
# ## RTHold missed analysis

# %%
nline_miss = nline_df[['Error', 'RT', 'RTHold', 'catch', 'Task', 'Line_pct']]
nline_miss = nline_miss[nline_miss['catch']<1]
len(nline_miss)
# Out:
# 1296

# %%
nline_miss['Missed'] = nline_miss['Error']
nline_miss['Missed'][nline_miss['Missed']<1] = 0
nline_miss
# Out:
#                         Error        RT    RTHold  catch  Task  Line_pct  \
# Subject Run   Trial
# s_02009 Run_3 1     -0.056388  2.325869  0.462052      0     2      0.90
#               2     -0.009471  2.011655  0.648239      0     2      0.45
#               3     -0.017137  2.045767  0.502666      0     2      0.57
#               5     -0.012731  2.794526  0.526923      0     2      0.07
#               6     -0.032115  1.928430  0.448109      0     2      0.77
#               7      0.000837  2.646016  0.498345      0     2      0.03
#               8      0.019075  2.011882  0.542642      0     2      0.21
#               9     -0.024449  2.176008  0.732567      0     2      0.65
#               11    -0.052643  2.495735  0.586613      0     2      0.85
#               12     0.039780  2.842913  0.597258      0     2      0.11
#               13     0.032159  1.942424  0.449394      0     2      0.60
#               15     0.020000  1.725692  0.454650      0     2      0.98
#               17    -0.006123  2.028588  0.536987      0     3      0.07
#               18     0.008590  1.894971  0.380307      0     3      0.65
#               19    -0.025595  2.428051  0.458853      0     3      0.03
#               20     0.014449  2.176045  0.469045      0     3      0.36
#               21     0.003744  1.611656  0.396948      0     3      0.45
#               22    -0.003921  1.943663  0.383196      0     3      0.57
#               24    -0.001806  2.662367  0.556490      0     3      0.33
#               26    -0.000881  2.442966  0.551099      0     3      0.60
#               27    -0.000749  2.343055  0.548913      0     3      0.21
#               29     0.009692  2.576140  0.594083      0     3      0.90
#               30    -0.024493  2.159518  0.453022      0     3      0.28
#               31    -0.006388  2.661703  0.555826      0     3      0.85
#               32    -0.002115  2.061149  0.470935      0     1      0.74
#               34     0.022907  2.309477  0.367291      0     1      0.90
#               35    -0.018899  2.342407  0.519901      0     1      0.77
#               37     0.020000  1.761958  0.342875      0     1      0.98
#               38    -0.030000  1.895479  0.322675      0     1      0.03
#               39    -0.011278  2.845445  0.674254      0     1      0.28
# ...                       ...       ...       ...    ...   ...       ...
# s_02011 Run_0 8     -0.068943  2.742358  0.742034      0     2      0.45
#               10     0.015154  2.345311  0.688266      0     2      0.28
#               12     1.000000 -1.000000  0.766947      0     2      0.98
#               13    -0.078370  2.708954  1.288470      0     2      0.77
#               14     0.035727  1.994472  0.643523      0     2      0.57
#               15    -0.082819  2.312302  0.527254      0     2      0.90
#               16     1.000000 -1.000000  0.448300      0     3      0.07
#               17     0.002379  2.808612  0.568785      0     3      0.98
#               18     0.012335  2.059484  0.428255      0     3      0.60
#               19     0.004802  2.045233  0.519361      0     3      0.33
#               20     0.028414  2.179456  0.623719      0     3      0.65
#               21     1.000000 -1.000000  0.870323      0     3      0.90
#               22    -0.006388  2.525986  0.497799      0     3      0.85
#               23     0.020749  2.662624  0.682748      0     3      0.77
#               24    -0.025595  2.696228  0.526577      0     3      0.03
#               27     0.011101  2.661476  0.456263      0     3      0.74
#               28    -0.007357  2.745879  0.598893      0     3      0.21
#               30     0.003744  2.228673  0.448477      0     3      0.45
#               32     1.000000 -1.000000  0.482817      0     1      0.03
#               35    -0.035903  1.912539  0.406209      0     1      0.45
#               36     0.037841  2.595622  0.701872      0     1      0.33
#               37     0.068018  2.494690  0.673230      0     1      0.28
#               38    -0.054978  2.728478  0.873799      0     1      0.74
#               39     0.008590  2.073084  0.561718      0     1      0.65
#               40     0.086388  2.595651  0.781628      0     1      0.07
#               41     0.015903  1.979101  0.489183      0     1      0.57
#               42    -0.072467  2.562353  0.595087      0     1      0.85
#               43     0.019956  2.909376  0.633590      0     1      0.11
#               44     0.001233  2.509307  0.616248      0     1      0.36
#               47     1.000000 -1.000000  0.508104      0     1      0.90
#
#                      Missed
# Subject Run   Trial
# s_02009 Run_3 1           0
#               2           0
#               3           0
#               5           0
#               6           0
#               7           0
#               8           0
#               9           0
#               11          0
#               12          0
#               13          0
#               15          0
#               17          0
#               18          0
#               19          0
#               20          0
#               21          0
#               22          0
#               24          0
#               26          0
#               27          0
#               29          0
#               30          0
#               31          0
#               32          0
#               34          0
#               35          0
#               37          0
#               38          0
#               39          0
# ...                     ...
# s_02011 Run_0 8           0
#               10          0
#               12          1
#               13          0
#               14          0
#               15          0
#               16          1
#               17          0
#               18          0
#               19          0
#               20          0
#               21          1
#               22          0
#               23          0
#               24          0
#               27          0
#               28          0
#               30          0
#               32          1
#               35          0
#               36          0
#               37          0
#               38          0
#               39          0
#               40          0
#               41          0
#               42          0
#               43          0
#               44          0
#               47          1
#
# [1296 rows x 7 columns]

# %%
responded = nline_miss[nline_miss['Missed']==0]
responded['Error'] = np.abs(responded['Error'])
len(responded)
# Out:
# -c:2: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# 1248

# %%
nline_miss = nline_miss[nline_miss['Missed']==1]
nline_miss
# Out:
#                      Error  RT    RTHold  catch  Task  Line_pct  Missed
# Subject Run   Trial
# s_02009 Run_0 22         1  -1  0.596069      0     2      0.07       1
# s_02003 Run_3 1          1  -1  0.510247      0     3      0.60       1
#         Run_2 20         1  -1  0.404079      0     3      0.74       1
#               23         1  -1  0.445901      0     3      0.33       1
#         Run_0 0          1  -1  1.083807      0     2      0.74       1
#               15         1  -1  0.504140      0     2      0.98       1
#               26         1  -1  0.573068      0     1      0.07       1
#               36         1  -1  0.538960      0     3      0.07       1
# s_02002 Run_0 9          1  -1  1.537010      0     2      0.28       1
#               29         1  -1  0.399618      0     1      0.11       1
# s_02001 Run_0 25         1  -1  0.399887      0     2      0.98       1
# s_02007 Run_3 24         1  -1  0.446265      0     1      0.85       1
# s_02006 Run_1 35         1  -1  0.282615      0     1      0.03       1
#         Run_0 12         1  -1  0.353787      0     3      0.60       1
# s_02005 Run_3 6          1  -1  0.430329      0     1      0.28       1
#               9          1  -1  0.469991      0     1      0.36       1
#               39         1  -1  0.363345      0     2      0.11       1
#         Run_2 13         1  -1  0.459736      0     2      0.07       1
#               22         1  -1  0.640726      0     3      0.85       1
#               47         1  -1  0.422893      0     1      0.33       1
#         Run_1 15         1  -1  0.374285      0     3      0.74       1
#               20         1  -1  0.546675      0     1      0.21       1
#               21         1  -1  0.489193      0     1      0.85       1
#               29         1  -1  0.399655      0     1      0.45       1
#         Run_0 0          1  -1  0.452760      0     1      0.07       1
#               7          1  -1  1.098877      0     1      0.11       1
#               20         1  -1  0.457945      0     2      0.98       1
#               32         1  -1  0.766867      0     3      0.90       1
#               34         1  -1  0.535520      0     3      0.21       1
#               36         1  -1  0.471375      0     3      0.45       1
#               43         1  -1  0.518343      0     3      0.07       1
# s_02004 Run_3 26         1  -1  0.379002      0     1      0.74       1
#         Run_1 17         1  -1  0.369379      0     3      0.77       1
#         Run_0 17         1  -1  0.366985      0     3      0.03       1
# s_02010 Run_3 19         1  -1  0.357919      0     2      0.03       1
#               27         1  -1  1.234647      0     2      0.74       1
#               32         1  -1  0.586040      0     3      0.74       1
#         Run_2 5          1  -1  0.326444      0     2      0.03       1
#               28         1  -1  0.354053      0     1      0.74       1
#         Run_0 0          1  -1  0.898591      0     3      0.85       1
#               34         1  -1  0.568070      0     2      0.85       1
# s_02011 Run_1 25         1  -1  0.494741      0     3      0.98       1
#               31         1  -1  0.532698      0     3      0.03       1
#         Run_0 12         1  -1  0.766947      0     2      0.98       1
#               16         1  -1  0.448300      0     3      0.07       1
#               21         1  -1  0.870323      0     3      0.90       1
#               32         1  -1  0.482817      0     1      0.03       1
#               47         1  -1  0.508104      0     1      0.90       1

# %%
nline_miss_subj = nline_miss.groupby(level=0)
nline_miss_subj.mean()
# Out:
#          Error  RT    RTHold  catch      Task  Line_pct  Missed
# Subject
# s_02001      1  -1  0.399887      0  2.000000  0.980000       1
# s_02002      1  -1  0.968314      0  1.500000  0.195000       1
# s_02003      1  -1  0.580029      0  2.428571  0.504286       1
# s_02004      1  -1  0.371789      0  2.333333  0.513333       1
# s_02005      1  -1  0.523442      0  1.882353  0.414118       1
# s_02006      1  -1  0.318201      0  2.000000  0.315000       1
# s_02007      1  -1  0.446265      0  1.000000  0.850000       1
# s_02009      1  -1  0.596069      0  2.000000  0.070000       1
# s_02010      1  -1  0.617966      0  2.142857  0.568571       1
# s_02011      1  -1  0.586275      0  2.285714  0.555714       1

# %%
nline_missed_subj.sum()
# Out:
# Subject
# s_02001     1
# s_02002     2
# s_02003     7
# s_02004     3
# s_02005    17
# s_02006     2
# s_02007     1
# s_02009     1
# s_02010     7
# s_02011     7
# Name: Missed, dtype: float64

# %%
np.mean(nline_miss_subj.mean())
# Out:
# Error       1.000000
# RT         -1.000000
# RTHold      0.540824
# catch       0.000000
# Task        1.957283
# Line_pct    0.496602
# Missed      1.000000
# dtype: float64

# %%
#dots_df.to_csv('Dots_data.csv', sep='\t')

# %%
responded_subj = responded.groupby(level=0)
responded_subj.mean()
# Out:
#             Error        RT    RTHold  catch      Task  Line_pct  Missed
# Subject
# s_02001  0.024830  2.154253  0.380134      0  2.000000  0.483380       0
# s_02002  0.037568  2.000478  0.426307      0  2.014286  0.528714       0
# s_02003  0.022472  2.240014  0.480898      0  1.978102  0.493212       0
# s_02004  0.020997  2.181841  0.390107      0  1.992908  0.493333       0
# s_02005  0.021902  2.378822  0.468106      0  2.015748  0.504409       0
# s_02006  0.026771  1.970216  0.422093      0  2.000000  0.496268       0
# s_02007  0.027687  2.117213  0.430258      0  2.006993  0.491259       0
# s_02009  0.019800  2.240575  0.499304      0  2.000000  0.496713       0
# s_02010  0.034298  1.801020  0.402272      0  1.992701  0.489927       0
# s_02011  0.031181  2.177101  0.512704      0  1.985401  0.490584       0

# %%
np.mean(responded_subj.mean())
# Out:
# Error       0.026751
# RT          2.126153
# RTHold      0.441218
# catch       0.000000
# Task        1.998614
# Line_pct    0.496780
# Missed      0.000000
# dtype: float64

# %%
responded['RT_Diff'] = responded['RT']-responded['RTHold']

# %%
responded_subj = responded.groupby(level=0)
responded_subj.mean()
# Out:
#             Error        RT    RTHold  catch      Task  Line_pct  Missed  \
# Subject
# s_02001  0.024830  2.154253  0.380134      0  2.000000  0.483380       0
# s_02002  0.037568  2.000478  0.426307      0  2.014286  0.528714       0
# s_02003  0.022472  2.240014  0.480898      0  1.978102  0.493212       0
# s_02004  0.020997  2.181841  0.390107      0  1.992908  0.493333       0
# s_02005  0.021902  2.378822  0.468106      0  2.015748  0.504409       0
# s_02006  0.026771  1.970216  0.422093      0  2.000000  0.496268       0
# s_02007  0.027687  2.117213  0.430258      0  2.006993  0.491259       0
# s_02009  0.019800  2.240575  0.499304      0  2.000000  0.496713       0
# s_02010  0.034298  1.801020  0.402272      0  1.992701  0.489927       0
# s_02011  0.031181  2.177101  0.512704      0  1.985401  0.490584       0
#
#           RT_Diff
# Subject
# s_02001  1.774119
# s_02002  1.574171
# s_02003  1.759116
# s_02004  1.791734
# s_02005  1.910716
# s_02006  1.548123
# s_02007  1.686955
# s_02009  1.741271
# s_02010  1.398747
# s_02011  1.664397

# %% [markdown]
# ## Plots by position

# %%
position_tasks = responded.groupby(['Task', 'Line_pct'])

# %%
responded.iloc[0:20]
# Out:
#                         Error        RT    RTHold  catch  Task  Line_pct  \
# Subject Run   Trial
# s_02009 Run_3 1      0.056388  2.325869  0.462052      0     2      0.90
#               2      0.009471  2.011655  0.648239      0     2      0.45
#               3      0.017137  2.045767  0.502666      0     2      0.57
#               5      0.012731  2.794526  0.526923      0     2      0.07
#               6      0.032115  1.928430  0.448109      0     2      0.77
#               7      0.000837  2.646016  0.498345      0     2      0.03
#               8      0.019075  2.011882  0.542642      0     2      0.21
#               9      0.024449  2.176008  0.732567      0     2      0.65
#               11     0.052643  2.495735  0.586613      0     2      0.85
#               12     0.039780  2.842913  0.597258      0     2      0.11
#               13     0.032159  1.942424  0.449394      0     2      0.60
#               15     0.020000  1.725692  0.454650      0     2      0.98
#               17     0.006123  2.028588  0.536987      0     3      0.07
#               18     0.008590  1.894971  0.380307      0     3      0.65
#               19     0.025595  2.428051  0.458853      0     3      0.03
#               20     0.014449  2.176045  0.469045      0     3      0.36
#               21     0.003744  1.611656  0.396948      0     3      0.45
#               22     0.003921  1.943663  0.383196      0     3      0.57
#               24     0.001806  2.662367  0.556490      0     3      0.33
#               26     0.000881  2.442966  0.551099      0     3      0.60
#
#                      Missed   RT_Diff
# Subject Run   Trial
# s_02009 Run_3 1           0  1.863817
#               2           0  1.363416
#               3           0  1.543101
#               5           0  2.267603
#               6           0  1.480321
#               7           0  2.147672
#               8           0  1.469241
#               9           0  1.443442
#               11          0  1.909122
#               12          0  2.245656
#               13          0  1.493030
#               15          0  1.271043
#               17          0  1.491601
#               18          0  1.514665
#               19          0  1.969198
#               20          0  1.707000
#               21          0  1.214707
#               22          0  1.560467
#               24          0  2.105877
#               26          0  1.891868

# %%
position_tasks['RT'].mean()
# Out:
# Task  Line_pct
# 1     0.03        2.112139
#       0.07        2.231324
#       0.11        2.213074
#       0.21        2.217518
#       0.28        2.293740
#       0.33        2.099332
#       0.36        2.153877
#       0.45        1.792014
#       0.57        1.843145
#       0.60        1.946878
#       0.65        1.933920
#       0.74        2.138354
#       0.77        2.226949
#       0.85        2.354721
#       0.90        2.316258
#       0.98        2.209369
# 2     0.03        2.191647
#       0.07        2.305264
#       0.11        2.301771
#       0.21        2.248535
#       0.28        2.119785
#       0.33        2.161787
#       0.36        2.032894
#       0.45        1.842799
#       0.57        1.892094
#       0.60        2.012187
#       0.65        1.996750
#       0.74        2.281286
#       0.77        2.150462
#       0.85        2.334746
#       0.90        2.318374
#       0.98        2.161132
# 3     0.03        2.224517
#       0.07        2.217191
#       0.11        2.284799
#       0.21        2.303382
#       0.28        2.128559
#       0.33        2.000015
#       0.36        1.962331
#       0.45        1.790413
#       0.57        1.864980
#       0.60        1.797620
#       0.65        1.935298
#       0.74        2.223587
#       0.77        2.226961
#       0.85        2.281470
#       0.90        2.272602
#       0.98        2.366154
# Name: RT, dtype: float64

# %%
rts = position_tasks['RT'].mean()

# %%
error = position_tasks['Error'].mean()

# %%
rts.iloc[10]
# Out:
# 1.933920047296346

# %%
rts_1 = rts.iloc[0:16]
rts_2 = rts.iloc[16:32]
rts_3 = rts.iloc[32:48]
#rts_1 = rts.iloc[0:14]
#rts_2 = rts.iloc[14:30]
#rts_3 = rts.iloc[30:46]

# %%
error_1 = error.iloc[0:16]
error_2 = error.iloc[16:32]
error_3 = error.iloc[32:48]
#error_1 = error.iloc[0:14]
#error_2 = error.iloc[14:30]
#error_3 = error.iloc[30:46]

# %%
rts_1 = rts_1.get_values()
rts_2 = rts_2.get_values()
rts_3 = rts_3.get_values()

# %%
error_1 = error_1.get_values()
error_2 = error_2.get_values()
error_3 = error_3.get_values()

# %%
xvals = np.array([0.030, 0.070, 0.110, 0.210, 0.280, 0.330, 0.360, 0.450, 0.570, 0.600, 0.650, 0.740, 0.770, 0.850, 0.900, 0.980])
len(rts_1)
xvals1 = np.array([0.030, 0.070, 0.110, 0.210, 0.280, 0.330, 0.360, 0.450, 0.570, 0.600, 0.650, 0.740, 0.900, 0.980])

# %%
len(rts_3)
# Out:
# 16

# %%
pylab.subplot(3,1,1)
pylab.plot(xvals, rts_1, 'ro-')
#pylab.plot(xvals1, rts_1, 'ro-')
pylab.title('Mean RT By Position')
pylab.xlabel('0 to 100', labelpad = 4)
pylab.ylabel('Mean RT')
pylab.ylim([1,3])
#pylab.ylim([0.8,3])
pylab.yticks(([1.5,2,2.5]))

pylab.subplot(3,1,2)
pylab.plot(xvals, rts_2, 'b+-')
pylab.xlabel('-100 to 100', labelpad = 4)
pylab.ylabel('Mean RT')
pylab.ylim([1,3])
#pylab.ylim([0.8,3])
pylab.yticks(([1.5,2,2.5,2.5]))

pylab.subplot(3,1,3)
pylab.plot(xvals, rts_3, 'y.-')
#pylab.plot(xvals1, rts_3, 'y.-')
pylab.xlabel('Word Task', labelpad = 4)
pylab.ylabel('Mean RT')
pylab.ylim([1,3])
#pylab.ylim([0.8,3])
pylab.yticks(([1.5,2,2.5]))

pylab.subplots_adjust(hspace = 1.1)

# %%
pylab.subplot(3,1,1)
pylab.plot(xvals, error_1, 'ro-')
#pylab.plot(xvals1, error_1, 'ro-')
pylab.title('Mean Absolute Error By Position')
pylab.xlabel('0 to 100', labelpad = 4)
pylab.ylabel('MAE')
pylab.ylim([0,0.085])
pylab.yticks(([0.0,0.033,0.066]))

pylab.subplot(3,1,2)
pylab.plot(xvals, error_2, 'b+-')
pylab.xlabel('-100 to 100', labelpad = 4)
pylab.ylabel('MAE')
pylab.ylim([0,0.085])
pylab.yticks(([0.0,0.033,0.066]))

pylab.subplot(3,1,3)
pylab.plot(xvals, error_3, 'y.-')
#pylab.plot(xvals1, error_3, 'y.-')
pylab.xlabel('Word Task', labelpad = 4)
pylab.ylabel('MAE')
pylab.ylim([0,0.085])
pylab.yticks(([0.0,0.033,0.066]))


pylab.subplots_adjust(hspace = 1.1)
