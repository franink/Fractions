# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from scipy import io
import os
import glob
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
from IPython.display import HTML

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
sns.set_style('white')
sns.set_style('ticks')
sns.set_palette('deep')
sns.set_color_codes('deep')

# %%
## Desktop
filepath = '/Users/frankanayet/Google Drive/NLineData/VogelData/'
os.chdir(filepath)

# %%
print 'Pandas version ' + pd.__version__
# Out:
# Pandas version 0.17.1

# %%
df = pd.read_csv('vogeldata.csv')

# %%
df.head(20)
# Out:
#     Age  id  conditionno  TrialTypefMRI  CorrectResponse   response  \
# 0    25   1            1              1           -99999   2.000000
# 1    25   1            3              1           -99999   2.000000
# 2    25   1            2              1           -99999   2.000000
# 3    25   1            1              1           -99999   2.000000
# 4    25   1            2              1           -99999   2.000000
# 5    25   1            3              1           -99999   2.000000
# 6    25   1            1              1           -99999   2.000000
# 7    25   1            2              1           -99999   2.000000
# 8    25   1            1              1           -99999   2.000000
# 9    25   1            3              1           -99999   2.000000
# 10   25   1            2              1           -99999   2.000000
# 11   25   1            3              1           -99999   2.000000
# 12   25   1            1              2                3   1.811125
# 13   25   1            1              2                3   2.069858
# 14   25   1            1              2                3   2.457956
# 15   25   1            1              2                7  11.384217
# 16   25   1            1              2                7   9.573092
# 17   25   1            1              2                7   8.020699
# 18   25   1            1              2               11   9.831824
# 19   25   1            1              2               11  11.125485
#
#             PAE    rt
# 0                1200
# 1                1018
# 2                 962
# 3                 907
# 4                 816
# 5                 914
# 6                 768
# 7                 779
# 8                 850
# 9                1052
# 10                887
# 11                664
# 12  1.188874515  3726
# 13  0.930142303  2994
# 14  0.542043984  3715
# 15  4.384217335  3270
# 16   2.57309185  4840
# 17  1.020698577  4358
# 18  1.168175938  3410
# 19  0.125485123  2549

# %%
len(df)
# Out:
# 2688

# %%
new_df = df.loc[df.CorrectResponse != -99999,:]
rem_prac = len(new_df)

# %%
new_df = new_df.rename(columns = {'id':'s_id'})
new_df.columns
# Out:
# Index([u'Age', u's_id', u'conditionno', u'TrialTypefMRI', u'CorrectResponse',
#        u'response', u'PAE', u'rt'],
#       dtype='object')

# %%
nsub = len(new_df.s_id.unique())

# %%
(len(df)-len(new_df))/14
# Out:
# 12

# %%
new_df['Missed'] = 0

# %%
new_df.loc[new_df['response'] == -99999, 'Missed'] =1
new_df.head(30)
# Out:
#     Age  s_id  conditionno  TrialTypefMRI  CorrectResponse      response  \
# 12   25     1            1              2                3      1.811125
# 13   25     1            1              2                3      2.069858
# 14   25     1            1              2                3      2.457956
# 15   25     1            1              2                7     11.384217
# 16   25     1            1              2                7      9.573092
# 17   25     1            1              2                7      8.020699
# 18   25     1            1              2               11      9.831824
# 19   25     1            1              2               11     11.125485
# 20   25     1            1              2               11     11.642950
# 21   25     1            1              2               13     15.265201
# 22   25     1            1              2               13     10.866753
# 23   25     1            1              2               13     13.454075
# 24   25     1            1              2               21     19.534282
# 25   25     1            1              2               21     18.628719
# 26   25     1            1              2               21     21.216041
# 27   25     1            1              2               28     28.331177
# 28   25     1            1              2               28     18.499353
# 29   25     1            1              2               28     23.932730
# 30   25     1            1              2               33 -99999.000000
# 31   25     1            1              2               33     30.789133
# 32   25     1            1              2               33     24.967658
# 33   25     1            1              2               36     37.257439
# 34   25     1            1              2               36     36.739974
# 35   25     1            1              2               36     39.327296
# 36   25     1            1              2               42     42.561449
# 37   25     1            1              2               42     42.432083
# 38   25     1            1              2               42     46.313066
# 39   25     1            1              2               45     47.477361
# 40   25     1            1              2               45     46.313066
# 41   25     1            1              2               45     43.596378
#
#             PAE    rt  Missed
# 12  1.188874515  3726       0
# 13  0.930142303  2994       0
# 14  0.542043984  3715       0
# 15  4.384217335  3270       0
# 16   2.57309185  4840       0
# 17  1.020698577  4358       0
# 18  1.168175938  3410       0
# 19  0.125485123  2549       0
# 20  0.642949547  4069       0
# 21  2.265200517  2529       0
# 22  2.133247089  4466       0
# 23  0.454075032  2610       0
# 24  1.465717982  2963       0
# 25  2.371280724  2942       0
# 26  0.216041397  3851       0
# 27  0.331177232  4657       0
# 28  9.500646831  3699       0
# 29  4.067270375  2996       0
# 30                  0       1
# 31  2.210866753  3017       0
# 32  8.032341527  3845       0
# 33  1.257438551  3293       0
# 34  0.739974127  3385       0
# 35  3.327296248  2898       0
# 36    0.5614489  2795       0
# 37  0.432082794  3491       0
# 38  4.313065977  4333       0
# 39  2.477360931  2857       0
# 40  1.313065977  4220       0
# 41  1.403622251  3407       0

# %%
new_df.Missed.sum()/nsub
# Out:
# 8

# %%
new_df.loc[new_df['response'] == -99999, ['response', 'PAE', 'rt']] = np.nan
new_df.head(30)
# Out:
#     Age  s_id  conditionno  TrialTypefMRI  CorrectResponse   response  \
# 12   25     1            1              2                3   1.811125
# 13   25     1            1              2                3   2.069858
# 14   25     1            1              2                3   2.457956
# 15   25     1            1              2                7  11.384217
# 16   25     1            1              2                7   9.573092
# 17   25     1            1              2                7   8.020699
# 18   25     1            1              2               11   9.831824
# 19   25     1            1              2               11  11.125485
# 20   25     1            1              2               11  11.642950
# 21   25     1            1              2               13  15.265201
# 22   25     1            1              2               13  10.866753
# 23   25     1            1              2               13  13.454075
# 24   25     1            1              2               21  19.534282
# 25   25     1            1              2               21  18.628719
# 26   25     1            1              2               21  21.216041
# 27   25     1            1              2               28  28.331177
# 28   25     1            1              2               28  18.499353
# 29   25     1            1              2               28  23.932730
# 30   25     1            1              2               33        NaN
# 31   25     1            1              2               33  30.789133
# 32   25     1            1              2               33  24.967658
# 33   25     1            1              2               36  37.257439
# 34   25     1            1              2               36  36.739974
# 35   25     1            1              2               36  39.327296
# 36   25     1            1              2               42  42.561449
# 37   25     1            1              2               42  42.432083
# 38   25     1            1              2               42  46.313066
# 39   25     1            1              2               45  47.477361
# 40   25     1            1              2               45  46.313066
# 41   25     1            1              2               45  43.596378
#
#             PAE    rt  Missed
# 12  1.188874515  3726       0
# 13  0.930142303  2994       0
# 14  0.542043984  3715       0
# 15  4.384217335  3270       0
# 16   2.57309185  4840       0
# 17  1.020698577  4358       0
# 18  1.168175938  3410       0
# 19  0.125485123  2549       0
# 20  0.642949547  4069       0
# 21  2.265200517  2529       0
# 22  2.133247089  4466       0
# 23  0.454075032  2610       0
# 24  1.465717982  2963       0
# 25  2.371280724  2942       0
# 26  0.216041397  3851       0
# 27  0.331177232  4657       0
# 28  9.500646831  3699       0
# 29  4.067270375  2996       0
# 30          NaN   NaN       1
# 31  2.210866753  3017       0
# 32  8.032341527  3845       0
# 33  1.257438551  3293       0
# 34  0.739974127  3385       0
# 35  3.327296248  2898       0
# 36    0.5614489  2795       0
# 37  0.432082794  3491       0
# 38  4.313065977  4333       0
# 39  2.477360931  2857       0
# 40  1.313065977  4220       0
# 41  1.403622251  3407       0

# %%
new_df['error'] = new_df.response - new_df.CorrectResponse
new_df.head(30)
# Out:
#     Age  s_id  conditionno  TrialTypefMRI  CorrectResponse   response  \
# 12   25     1            1              2                3   1.811125
# 13   25     1            1              2                3   2.069858
# 14   25     1            1              2                3   2.457956
# 15   25     1            1              2                7  11.384217
# 16   25     1            1              2                7   9.573092
# 17   25     1            1              2                7   8.020699
# 18   25     1            1              2               11   9.831824
# 19   25     1            1              2               11  11.125485
# 20   25     1            1              2               11  11.642950
# 21   25     1            1              2               13  15.265201
# 22   25     1            1              2               13  10.866753
# 23   25     1            1              2               13  13.454075
# 24   25     1            1              2               21  19.534282
# 25   25     1            1              2               21  18.628719
# 26   25     1            1              2               21  21.216041
# 27   25     1            1              2               28  28.331177
# 28   25     1            1              2               28  18.499353
# 29   25     1            1              2               28  23.932730
# 30   25     1            1              2               33        NaN
# 31   25     1            1              2               33  30.789133
# 32   25     1            1              2               33  24.967658
# 33   25     1            1              2               36  37.257439
# 34   25     1            1              2               36  36.739974
# 35   25     1            1              2               36  39.327296
# 36   25     1            1              2               42  42.561449
# 37   25     1            1              2               42  42.432083
# 38   25     1            1              2               42  46.313066
# 39   25     1            1              2               45  47.477361
# 40   25     1            1              2               45  46.313066
# 41   25     1            1              2               45  43.596378
#
#             PAE    rt  Missed     error
# 12  1.188874515  3726       0 -1.188875
# 13  0.930142303  2994       0 -0.930142
# 14  0.542043984  3715       0 -0.542044
# 15  4.384217335  3270       0  4.384217
# 16   2.57309185  4840       0  2.573092
# 17  1.020698577  4358       0  1.020699
# 18  1.168175938  3410       0 -1.168176
# 19  0.125485123  2549       0  0.125485
# 20  0.642949547  4069       0  0.642950
# 21  2.265200517  2529       0  2.265201
# 22  2.133247089  4466       0 -2.133247
# 23  0.454075032  2610       0  0.454075
# 24  1.465717982  2963       0 -1.465718
# 25  2.371280724  2942       0 -2.371281
# 26  0.216041397  3851       0  0.216041
# 27  0.331177232  4657       0  0.331177
# 28  9.500646831  3699       0 -9.500647
# 29  4.067270375  2996       0 -4.067270
# 30          NaN   NaN       1       NaN
# 31  2.210866753  3017       0 -2.210867
# 32  8.032341527  3845       0 -8.032342
# 33  1.257438551  3293       0  1.257439
# 34  0.739974127  3385       0  0.739974
# 35  3.327296248  2898       0  3.327296
# 36    0.5614489  2795       0  0.561449
# 37  0.432082794  3491       0  0.432083
# 38  4.313065977  4333       0  4.313066
# 39  2.477360931  2857       0  2.477361
# 40  1.313065977  4220       0  1.313066
# 41  1.403622251  3407       0 -1.403622

# %% [markdown]
# # How many missed by subj?

# %%
new_df.loc[:,'conditionno'] = new_df['conditionno'].replace([1,2,3],['1_Number', '2_Luminance', '3_Word'])

# %%
new_df[['s_id', 'Missed']].groupby('s_id').sum()
# Out:
#       Missed
# s_id
# 1         10
# 2         11
# 3         17
# 5          5
# 6          6
# 7          3
# 8         10
# 10        12
# 11         9
# 12         2
# 13         5
# 16        13
# 17         2
# 18         8

# %%
new_df[['s_id', 'conditionno', 'Missed']].groupby(['s_id', 'conditionno']).sum()
# Out:
#                   Missed
# s_id conditionno
# 1    1_Number          3
#      2_Luminance       3
#      3_Word            4
# 2    1_Number          4
#      2_Luminance       2
#      3_Word            5
# 3    1_Number          2
#      2_Luminance       4
#      3_Word           11
# 5    1_Number          3
#      2_Luminance       1
#      3_Word            1
# 6    1_Number          1
#      2_Luminance       2
#      3_Word            3
# 7    1_Number          0
#      2_Luminance       2
#      3_Word            1
# 8    1_Number          5
#      2_Luminance       1
#      3_Word            4
# 10   1_Number          4
#      2_Luminance       2
#      3_Word            6
# 11   1_Number          7
#      2_Luminance       0
#      3_Word            2
# 12   1_Number          1
#      2_Luminance       1
#      3_Word            0
# 13   1_Number          2
#      2_Luminance       2
#      3_Word            1
# 16   1_Number          6
#      2_Luminance       4
#      3_Word            3
# 17   1_Number          0
#      2_Luminance       1
#      3_Word            1
# 18   1_Number          3
#      2_Luminance       4
#      3_Word            1

# %%
new_df[['conditionno', 'CorrectResponse', 'Missed']].groupby(['conditionno', 'CorrectResponse']).sum()
# Out:
#                              Missed
# conditionno CorrectResponse
# 1_Number    3                     0
#             7                     2
#             11                    3
#             13                    1
#             21                    1
#             28                    0
#             33                   11
#             36                    2
#             42                    1
#             45                    0
#             56                    1
#             57                    4
#             60                    2
#             65                    4
#             74                    1
#             77                    2
#             83                    1
#             85                    0
#             90                    3
#             98                    2
# 2_Luminance 3                     0
#             7                     1
#             11                    1
#             13                    5
#             21                    3
#             28                    2
#             33                    1
#             36                    0
#             42                    1
#             45                    1
#             56                    1
#             57                    1
#             60                    2
#             65                    2
#             74                    0
#             77                    3
#             83                    0
#             85                    1
#             90                    0
#             98                    4
# 3_Word      3                     7
#             7                     1
#             11                    4
#             13                    5
#             21                    3
#             28                    0
#             33                    1
#             36                    0
#             42                    0
#             45                    4
#             56                    0
#             57                    0
#             60                    0
#             65                    0
#             74                    1
#             77                    1
#             83                    0
#             85                    4
#             90                    2
#             98                   10

# %%
pal = sns.color_palette()

# %% [markdown]
# # Histograms

# %%
new_df.loc[new_df['rt']<1000, ['response', 'PAE', 'rt', 'error']] = np.nan

# %%
sns.distplot(new_df.rt.dropna(), kde= False, color=pal[0])
plt.title('Overall RT')

# %%
sns.distplot(new_df.loc[new_df['conditionno']=='1_Number','rt'].dropna(), kde=False, color=pal[0])
plt.title('Number RT')
plt.ylim([0,100])
plt.xlim([500,5000])
# Out:
# (500, 5000)

# %%
sns.distplot(new_df.loc[new_df['conditionno']=='2_Luminance','rt'].dropna(), kde=False, color=pal[1])
plt.title('Luminance RT')
plt.ylim([0,100])
plt.xlim([500,5000])
# Out:
# (500, 5000)

# %%
sns.distplot(new_df.loc[new_df['conditionno']=='3_Word','rt'].dropna(), kde=False, color=pal[2])
plt.title('Word RT')
plt.ylim([0,100])
plt.xlim([500,5000])
# Out:
# (500, 5000)

# %%
new_df.PAE = new_df.PAE.astype(float)

# %% [markdown]
# Age is inconsistent in their data, some subjects have different ages associated with different trials

# %%
new_df[['s_id','PAE', 'rt','error']].groupby('s_id').mean()
# Out:
#             PAE           rt      error
# s_id
# 1      8.431337  3089.811765  -7.666646
# 2      4.956398  3170.757396  -3.970139
# 3     11.403400  3407.644172 -10.929682
# 5      3.961560  2923.977143   0.149266
# 6      4.139819  3415.333333  -3.330791
# 7      5.923162  3233.338983  -5.185132
# 8      7.171859  3345.647059  -5.541116
# 10     3.493293  3566.875000  -2.215294
# 11     7.291399  3232.900585  -6.759213
# 12     4.964257  3847.331461  -4.161853
# 13     7.387684  3329.720000  -6.035461
# 16     9.575207  3531.281437  -8.884531
# 17     7.169359  3126.857955  -6.469827
# 18     8.834945  3265.709302  -8.378674

# %%
new_df[['s_id', 'conditionno','PAE', 'rt','error']].groupby(['s_id', 'conditionno']).mean()
# Out:
#                         PAE           rt      error
# s_id conditionno
# 1    1_Number      2.145526  3318.649123  -0.539525
#      2_Luminance  22.330315  3082.982456 -22.128231
#      3_Word        0.682221  2863.839286  -0.201210
# 2    1_Number      3.431251  3306.892857  -2.563297
#      2_Luminance  10.424477  2868.724138  -8.835638
#      3_Word        0.742938  3350.654545  -0.271669
# 3    1_Number      1.934068  3527.879310  -0.781505
#      2_Luminance  30.883201  3231.982143 -30.806413
#      3_Word        0.349368  3466.081633  -0.225546
# 5    1_Number      3.048365  2872.736842  -1.955380
#      2_Luminance   8.501831  2931.847458   2.449734
#      3_Word        0.303528  2965.610169  -0.117899
# 6    1_Number      1.849738  3578.355932  -0.771526
#      2_Luminance  10.043561  3431.155172  -9.084289
#      3_Word        0.502939  3230.491228  -0.125417
# 7    1_Number      2.215050  3171.966667  -0.420354
#      2_Luminance  15.486550  3343.551724 -15.344649
#      3_Word        0.292828  3187.406780  -0.043349
# 8    1_Number      2.767588  3376.363636  -1.484888
#      2_Luminance  17.719276  3274.220339 -14.315500
#      3_Word        0.385026  3390.732143  -0.280470
# 10   1_Number      1.583718  3744.839286  -0.296341
#      2_Luminance   8.235402  3593.603448  -5.934380
#      3_Word        0.380217  3353.611111  -0.210747
# 11   1_Number      1.711514  3472.358491  -0.536235
#      2_Luminance  19.110608  3171.016667 -18.781716
#      3_Word        0.163492  3078.103448  -0.008654
# 12   1_Number      2.765606  3904.677966  -1.354770
#      2_Luminance  12.079396  3954.220339 -11.157564
#      3_Word        0.129711  3685.833333  -0.043036
# 13   1_Number      4.092675  3593.206897  -1.010327
#      2_Luminance  17.713008  3312.862069 -17.179797
#      3_Word        0.476528  3087.271186  -0.019975
# 16   1_Number      2.133439  3612.722222  -0.273490
#      2_Luminance  25.957794  3888.660714 -25.939683
#      3_Word        0.530129  3103.017544  -0.286421
# 17   1_Number      2.086127  3266.237288  -0.839652
#      2_Luminance  19.206161  3057.120690 -18.585694
#      3_Word        0.419804  3056.033898  -0.189488
# 18   1_Number      2.081546  3320.473684  -0.880257
#      2_Luminance  24.598411  3326.125000 -24.598411
#      3_Word        0.397483  3155.457627  -0.227904

# %%
new_df = new_df.sort_values(by='CorrectResponse')

# %% [markdown]
# ## RT boxplots

# %%
plt_df = new_df.copy()
plt_df = plt_df.groupby(['conditionno','CorrectResponse','s_id']).mean()
plt_df.to_csv('plot_data_vogel.csv', sep='\t')
plt_df = pd.read_csv('plot_data_vogel.csv',sep='\t')

# %%
ax = sns.factorplot(x='CorrectResponse',y='rt',hue='conditionno',row='conditionno',data=plt_df,kind='box',size=4,aspect=3)
sns.despine(trim=True)

# %%
plt.figure(figsize=(14,6))
for key,grp in plt_df.groupby('conditionno'):
    print
    plt.plot(grp.CorrectResponse.unique(),grp.groupby('CorrectResponse')['rt'].median(),'-o',label=key)
plt.legend(loc = 'best')
#plt.ylim([1.4,2.6])
plt.xlabel('Line_pct')
plt.ylabel('Median RT')
sns.despine(trim=True)

# %%
g = sns.FacetGrid(plt_df, row='conditionno',hue='conditionno',palette=pal,size=4,aspect=3)
g = g.map(sns.regplot, 'CorrectResponse', 'rt', fit_reg=False,x_estimator=np.median).set(xlim=(0,100))
sns.despine(trim=True)

# %% [markdown]
# # MAE boxplots

# %% [markdown]
# With means for each subject

# %%
ax = sns.factorplot(x='CorrectResponse',y='PAE',hue='conditionno',row='conditionno',data=plt_df,kind='box',size=4,
                    aspect=3,sharey=True)
sns.despine(trim=True)

# %% [markdown]
# ## Same plot as above but with different y axis to see pattern better

# %%
ax = sns.factorplot(x='CorrectResponse',y='PAE',hue='conditionno',row='conditionno',data=plt_df,kind='box',size=4,
                    aspect=3,sharey=False)
sns.despine(trim=True)

# %%
plt.figure(figsize=(14,6))
for key,grp in plt_df.groupby('conditionno'):
    print 
    plt.plot(grp.CorrectResponse.unique(),grp.groupby('CorrectResponse')['PAE'].median(),'-o',label=key)
plt.legend(loc = 'best')
#plt.ylim([0,0.06])
plt.xlabel('CorrectResponse')
plt.ylabel('Absolute Error')
sns.despine(trim=True)

# %%
g = sns.FacetGrid(plt_df, row='conditionno',hue='conditionno',palette=pal,size=4,aspect=3, sharey=False)
g = g.map(sns.regplot, 'CorrectResponse', 'PAE', fit_reg=False,x_estimator=np.median,).set(xlim=(0,100))
sns.despine(trim=True)

# %% [markdown]
# ## Signed Error

# %%
ax = sns.factorplot(x='CorrectResponse',y='error',hue='conditionno',row='conditionno',data=plt_df,kind='box',size=4,
                    aspect=3,sharey=True)
sns.despine(trim=True)
ax.map(plt.axhline, y=0, color='black')

# %% [markdown]
# ## Same plot as above but with different y axis to see pattern

# %%
ax = sns.factorplot(x='CorrectResponse',y='error',hue='conditionno',row='conditionno',data=plt_df,kind='box',size=4,
                    aspect=3,sharey=False)
sns.despine(trim=True)
ax.map(plt.axhline, y=0, color='black')

# %%
plt.figure(figsize=(14,6))
plt.plot(plt_df[plt_df['conditionno']=='1_Number'].CorrectResponse.unique(),plt_df[plt_df['conditionno']=='1_Number'].groupby('CorrectResponse')['error'].median(),'-o')
plt.axhline(y=0,color='black')
plt.legend(loc = 'best')
#plt.ylim([-.06,0.06])
plt.xlabel('CorrectResponse')
plt.ylabel('Signed Error')
sns.despine(trim=True)

# %%
plt.figure(figsize=(14,6))
for key,grp in plt_df.groupby('conditionno'):
    print 
    plt.plot(grp.CorrectResponse.unique(),grp.groupby('CorrectResponse')['error'].median(),'-o',label=key)
plt.axhline(y=0,color='black')
plt.legend(loc = 'best')
#plt.ylim([-.06,0.06])
plt.xlabel('CorrectResponse')
plt.ylabel('Signed Error')
sns.despine(trim=True)

# %%
g = sns.FacetGrid(plt_df, row='conditionno',hue='conditionno',palette=pal,size=4,aspect=3)
g = g.map(sns.regplot, 'CorrectResponse', 'error', fit_reg=False,x_estimator=np.median).set(xlim=(0,100))
sns.despine(trim=True)
for ax in g.axes.flat:
    ax.plot((0,100),(0,0),c='black')

# %% [markdown]
# ## SD Error boxplot

# %%
sd_df = new_df.copy()

# %%
sd_df = sd_df.groupby(['conditionno','CorrectResponse','s_id']).std()

# %%
sd_df.to_csv('plot_data_SD_Vogel.csv', sep='\t')
sd_df = pd.read_csv('plot_data_SD_Vogel.csv',sep='\t')

# %%
ax = sns.factorplot(x='CorrectResponse',y='error',hue='conditionno',row='conditionno',data=sd_df,kind='box',size=4,
                    aspect=3,sharey=True)
sns.despine(trim=True)
(ax.set_axis_labels("Line_pct",'SD Error'))

# %%
plt.figure(figsize=(14,6))
for key,grp in sd_df.groupby('conditionno'):
    print 
    plt.plot(grp.CorrectResponse.unique(),grp.groupby('CorrectResponse')['error'].median(),'-o',label=key)
plt.axhline(y=0,color='black')
plt.legend(loc = 'best')
#plt.ylim([0,0.04])
plt.xlabel('Line_pct')
plt.ylabel('SD Error')
sns.despine(trim=True)

# %%
g = sns.FacetGrid(sd_df, row='conditionno',hue='conditionno',palette=pal,size=4,aspect=3)
g = g.map(sns.regplot, 'CorrectResponse', 'error', fit_reg=False,x_estimator=np.median).set(xlim=(0,100))
sns.despine(trim=True)

# %% [markdown]
# ## Landmark Vs. MAE

# %%
plt_df.loc[:,'dist0'] = plt_df.CorrectResponse

# %%
plt_df.loc[:,'dist50'] = abs(plt_df.dist0 - 50)

# %%
plt_df.loc[:,'dist100'] = abs(plt_df.dist0 - 100)

# %%
plt_df.loc[:,'distLand'] = plt_df[['dist0','dist50','dist100']].min(1)

# %%
g = sns.lmplot(x='distLand',y='PAE',hue='conditionno',row='conditionno',data=plt_df,size=4,aspect=3)

# %%
g = sns.lmplot(x='distLand',y='PAE',hue='conditionno',row='conditionno',data=plt_df,size=4,aspect=3,sharey=False)

# %% [markdown]
# ## Landmark distance Vs signed error

# %%
g = sns.lmplot(x='distLand',y='error',hue='conditionno',row='conditionno',data=plt_df,size=4,aspect=3,sharey=False)

# %% [markdown]
# # Median Estimated Position

# %%
g = sns.lmplot(x='CorrectResponse',y='response',hue='conditionno',row='conditionno',data=plt_df,x_estimator=np.median,
               size=4,aspect=3).set(xlim=(0,100),ylim=(0,100))

# %%
from scipy.optimize import curve_fit
def exp_fit(x, a, b):
    return a + np.exp(b * x)

# %%
len(plt_df.loc[plt_df['conditionno'] == '1_Number','CorrectResponse'])
# Out:
# 280

# %%
len(plt_df.loc[plt_df['conditionno'] == '1_Number','response'])
# Out:
# 280

# %%
popt,pcov = curve_fit(exp_fit, plt_df.loc[plt_df['conditionno'] == '1_Number','CorrectResponse'],
                  plt_df.loc[plt_df['conditionno'] == '1_Number','response'])

# %%
plt.plot(plt_df.loc[plt_df['conditionno'] == '1_Number','CorrectResponse'],
        plt_df.loc[plt_df['conditionno'] == '1_Number','response'], 'bo',label='Data')
plt.plot(plt_df.loc[plt_df['conditionno'] == '1_Number','CorrectResponse'],
        exp_fit(plt_df.loc[plt_df['conditionno'] == '1_Number','CorrectResponse'], *popt),
         'b-', label='Fitted curve')
plt.legend()

# %%
popt,pcov = curve_fit(exp_fit, plt_df.loc[plt_df['conditionno'] == '2_Luminance','CorrectResponse'],
                  plt_df.loc[plt_df['conditionno'] == '2_Luminance','response'])

# %%
plt.plot(plt_df.loc[plt_df['conditionno'] == '2_Luminance','CorrectResponse'],
        plt_df.loc[plt_df['conditionno'] == '2_Luminance','response'], 'go',label='Data')
plt.plot(plt_df.loc[plt_df['conditionno'] == '2_Luminance','CorrectResponse'],
        exp_fit(plt_df.loc[plt_df['conditionno'] == '2_Luminance','CorrectResponse'], *popt),
         'g-', label='Fitted curve')
plt.legend()

# %%
print "a = %s , b = %s" % (popt[0], popt[1])
# Out:
# a = 13.1286371973 , b = 0.0458427189661

# %%
def resid(a,x,y):
    return y - exp_fit(x,a[0],a[1])

# %%
from scipy.optimize import leastsq

# %%
popt,pcov = curve_fit(exp_fit, plt_df.loc[plt_df['conditionno'] == '2_Luminance','CorrectResponse'],
                  plt_df.loc[plt_df['conditionno'] == '2_Luminance','response'])

# %%
residuals = resid(popt,plt_df.loc[plt_df['conditionno'] == '2_Luminance','CorrectResponse'],
                  plt_df.loc[plt_df['conditionno'] == '2_Luminance','response'])

# %%
preds = exp_fit(plt_df.loc[plt_df['conditionno'] == '2_Luminance','CorrectResponse'], *popt)

# %%
x = plt_df.loc[plt_df['conditionno'] == '2_Luminance','CorrectResponse']
y = plt_df.loc[plt_df['conditionno'] == '2_Luminance','response']

# %%
p,cov,infodict,mesg,ier = leastsq(
        resid,popt,args=(x,y),full_output=True)

# %%
ssErr = (infodict['fvec']**2).sum()

# %%
ssTot = ((y-y.mean())**2).sum()
rsquared = 1-(ssErr/ssTot )

# %%
rsquared
# Out:
# 0.7914973794700112

# %% [markdown]
# ## Compression Index

# %%
comp_df = plt_df.copy()

# %%
comp_df.columns
# Out:
# Index([u'conditionno', u'CorrectResponse', u's_id', u'Age', u'TrialTypefMRI',
#        u'response', u'PAE', u'rt', u'Missed', u'error', u'dist0', u'dist50',
#        u'dist100', u'distLand'],
#       dtype='object')

# %%
comp_df.loc[comp_df.CorrectResponse>75,'error'] = comp_df[comp_df.CorrectResponse>75]['error'] * -1

# %%
n_comp_trials = comp_df.loc[(comp_df.CorrectResponse<25)|(comp_df.CorrectResponse>75),
                       ['s_id','conditionno', 'error']].groupby(['conditionno','s_id']).count()

# %%
std_comp_trials = comp_df.loc[(comp_df.CorrectResponse<25)|(comp_df.CorrectResponse>75),
                       ['s_id','conditionno', 'error']].groupby(['conditionno','s_id']).std()

# %%
se_comp_trials = std_comp_trials/np.sqrt(n_comp_trials)

# %%
combined = comp_df.loc[(comp_df.CorrectResponse<25)|(comp_df.CorrectResponse>75),
                       ['s_id','conditionno', 'error']].groupby(['conditionno','s_id']).mean()

# %%
plt.hist(combined.loc['1_Number']['error'],color=pal[0])
plt.ylim([0,8])
#plt.xlim([-0.04,0.06])
plt.title('Positive')
sns.despine()

# %%
plt.hist(combined.loc['2_Luminance']['error'],color=pal[1])
plt.ylim([0,8])
#plt.xlim([-0.04,0.06])
plt.title('Luminance')
sns.despine()

# %%
combined['std_error'] = se_comp_trials

# %%
combined['CI_Low'] = combined.error - 1.96*(combined.std_error)

# %%
combined['CI_High'] = combined.error + 1.96*(combined.std_error)

# %%
combined['expanded'] = combined.CI_High < 0

# %%
combined.loc['1_Number'].expanded.sum()
# Out:
# 1

# %%
combined['compressed'] = combined.CI_Low > 0

# %%
combined.loc['1_Number'].compressed.sum()
# Out:
# 2

# %%
combined.loc['1_Number'].expanded.count()
# Out:
# 14

# %%
combined.loc['2_Luminance'].expanded.sum()
# Out:
# 0

# %%
combined.loc['2_Luminance'].compressed.sum()
# Out:
# 5

# %%
combined.loc['3_Word'].expanded.sum()
# Out:
# 0

# %%
combined.loc['3_Word'].compressed.sum()
# Out:
# 0

# %%
correl = np.corrcoef(combined.loc['1_Number']['error'],
                     combined.loc['2_Luminance']['error'])
correl[0,1]
# Out:
# -0.2773737374411116

# %%
corr_legend = 'r = {0:.2f}'.format(correl[0,1])
corr_legend
# Out:
# 'r = -0.28'

# %%
plt.scatter(combined.loc['1_Number']['error'],combined.loc['2_Luminance']['error'],s=35)
plt.xlabel('Positive Compression Index')
plt.ylabel('Luminance Compression Index')
plt.figtext(.85,.85,corr_legend)
sns.despine()

# %%
combined.to_csv('Vogel_Compression.csv')

# %%
1/14.0
# Out:
# 0.07142857142857142

# %%
combined.loc['1_Number'].error.mean()/100.0
# Out:
# 0.0054456354346182

# %%
combined.loc['1_Number'].error.std()/100.0
# Out:
# 0.009652415937952744
